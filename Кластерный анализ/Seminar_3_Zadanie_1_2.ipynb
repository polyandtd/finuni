# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %matplotlib inline

import os

# %% [markdown]
# ***1. Провести чтение данных, изучить набор данных.***

# %%
df = pd.read_csv('yieldinrf.csv')
df
# Out:
#                                            Unnamed: 0 1976- \n1980  \
# 0        Зерновые культуры (в весе \nпосле доработки)         13,8
# 1                                      пшеница озимая         21,6
# 2                                      пшеница яровая         12,2
# 3                                         рожь озимая         11,1
# 4                                   кукуруза на зерно         27,8
# 5                                       ячмень озимый         28,4
# 6                                       ячмень яровой         13,9
# 7                                                овес         12,2
# 8                                               просо          6,3
# 9                                             гречиха          4,0
# 10                                                рис         34,5
# 11                                       зернобобовые         11,1
# 12                             Лен-долгунец (волокно)          2,5
# 13                        Сахарная свекла (фабричная)          158
# 14                                 Масличные культуры          8,4
# 15                                       подсолнечник          9,9
# 16                                                соя          6,5
# 17                                          Картофель          106
# 18                                              Овощи          143
# 19          Кукуруза на силос, зеленый \nкорм и сенаж          140
# 20  Кормовые корнеплоды (включая сахарную свеклу н...          162
# 21                              Сено многолетних трав         18,5
# 22                               Сено однолетних трав         15,8
# 23  Сено естественных сенокосов (включая улучшенны...          7,6
#
#    1981 - 1985 1986- \n1990 1991- \n1995 1996-\n2000  2001  2002  2003  2004  \
# 0         13,0         16,5         15,7        15,1  19,4  19,6  17,8  18,8
# 1         20,1         28,5         24,3        21,3  29,1  29,9  21,2  29,4
# 2         11,0         12,3         11,7        12,7  15,7  14,4  14,8  13,8
# 3         13,0         16,7         15,9        15,0  18,8  19,0  18,6  15,5
# 4         29,0         29,8         27,6        22,4  18,0  28,5  32,0  40,3
# 5         27,9         37,3         32,3        30,4  36,3  39,4  26,3  37,4
# 6         12,2         15,6         15,7        14,7  19,0  18,3  19,1  16,8
# 7         12,3         13,8         13,6        13,6  17,1  15,6  16,8  15,1
# 8          8,1         12,9          8,1         9,0   7,9   8,5  13,9  11,9
# 9          4,1          6,2          5,2         6,0   5,4   5,4   8,2   7,5
# 10        33,7         35,4         29,2        28,2  34,9  37,7  31,5  37,7
# 11         9,9         11,9         12,4        12,9  17,9  15,9  14,8  16,2
# 12         2,9          3,2          3,8         4,0   5,0   4,7   6,6   5,8
# 13         166          230          179         177   199   219   227   277
# 14         8,3         11,8          9,9         8,4   7,9   9,8   9,9  10,2
# 15        10,0         13,3         10,5         8,5   7,8   9,7  10,0  10,2
# 16         5,7         10,6          8,8         8,4   9,4  11,7   9,8  10,0
# 17         104          110          110         105   109   103   116   115
# 18         157          163          145         146   155   152   168   167
# 19         163          200          148         133   119   118   153   157
# 20         183          247          219         214   209   199   228   230
# 21        23,3         26,3         19,8        14,3  15,8  14,8  15,2  15,7
# 22        17,1         20,0         15,6        14,4  15,6  15,8  16,2  15,7
# 23         8,5          9,4          8,5         7,7   8,0   8,0   8,0   8,0
#
#     2005  2006
# 0   18,5  18,9
# 1   28,3  28,0
# 2   13,0  14,3
# 3   15,7  17,1
# 4   38,5  36,2
# 5   32,4  36,3
# 6   17,3  18,0
# 7   14,4  14,7
# 8   11,2  10,4
# 9    7,3   8,1
# 10  42,0  43,9
# 11  15,4  16,0
# 12   6,3   6,1
# 13   282   325
# 14  11,7  11,2
# 15  11,9  11,4
# 16  10,5   9,9
# 17   121   130
# 18   175   179
# 19   164   157
# 20   238   258
# 21  16,4  15,6
# 22  16,4  16,3
# 23   8,4   7,6

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '1976- \n1980', '1981 - 1985', '1986- \n1990',
#        '1991- \n1995', '1996-\n2000', '2001', '2002', '2003', '2004', '2005',
#        '2006'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns = ['type', '1976-1980', '1981-1985', '1986-1990',
       '1991-1995', '1996-2000', '2001', '2002', '2003', '2004', '2005',
       '2006']

# %%
for col in df.columns:
    for i in range(len(df)):
        df.loc[i, col] = df.loc[i, col].replace(',', '.')

# %%
for col in df.columns[1:]:
    df[col] = df[col].astype(float)

# %% [markdown]
# ***2. Провести описательную статистику данных.***

# %%
df.shape
# Out:
# (24, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 12 columns):
# type         24 non-null object
# 1976-1980    24 non-null float64
# 1981-1985    24 non-null float64
# 1986-1990    24 non-null float64
# 1991-1995    24 non-null float64
# 1996-2000    24 non-null float64
# 2001         24 non-null float64
# 2002         24 non-null float64
# 2003         24 non-null float64
# 2004         24 non-null float64
# 2005         24 non-null float64
# 2006         24 non-null float64
# dtypes: float64(11), object(1)
# memory usage: 2.4+ KB

# %%
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_columns', 500)

# %%
df.describe()
# Out:
#         1976-1980   1981-1985   1986-1990  1991-1995   1996-2000        2001  \
# count   24.000000   24.000000   24.000000    24.0000   24.000000   24.000000
# mean    40.629167   43.462500   53.395833    45.4000   43.416667   45.833333
# std     54.358660   60.057681   75.641445    62.9469   61.357454   62.371305
# min      2.500000    2.900000    3.200000     3.8000    4.000000    5.000000
# 25%      9.525000    9.550000   12.200000    10.3500    8.875000    9.050000
# 50%     13.850000   13.000000   16.600000    15.7000   14.550000   17.950000
# 75%     29.925000   30.175000   35.875000    29.9750   28.750000   35.250000
# max    162.000000  183.000000  247.000000   219.0000  214.000000  209.000000
#
#              2002        2003        2004        2005        2006
# count   24.000000   24.000000   24.000000   24.000000   24.000000
# mean    46.570833   50.112500   53.416667   54.816667   57.875000
# std     62.760230   70.523677   76.577245   79.133155   86.856044
# min      4.700000    6.600000    5.800000    6.300000    6.100000
# 25%     11.225000   12.925000   11.475000   11.850000   11.350000
# 50%     17.100000   17.300000   15.950000   16.400000   16.700000
# 75%     38.125000   31.625000   38.350000   39.375000   38.200000
# max    219.000000  228.000000  277.000000  282.000000  325.000000

# %%
df.isna().sum()
# Out:
# type         0
# 1976-1980    0
# 1981-1985    0
# 1986-1990    0
# 1991-1995    0
# 1996-2000    0
# 2001         0
# 2002         0
# 2003         0
# 2004         0
# 2005         0
# 2006         0
# dtype: int64

# %%
df
# Out:
#                                                                                     type  \
# 0                                           Зерновые культуры (в весе \nпосле доработки)
# 1                                                                         пшеница озимая
# 2                                                                         пшеница яровая
# 3                                                                            рожь озимая
# 4                                                                      кукуруза на зерно
# 5                                                                          ячмень озимый
# 6                                                                          ячмень яровой
# 7                                                                                   овес
# 8                                                                                  просо
# 9                                                                                гречиха
# 10                                                                                   рис
# 11                                                                          зернобобовые
# 12                                                                Лен-долгунец (волокно)
# 13                                                           Сахарная свекла (фабричная)
# 14                                                                    Масличные культуры
# 15                                                                          подсолнечник
# 16                                                                                   соя
# 17                                                                             Картофель
# 18                                                                                 Овощи
# 19                                             Кукуруза на силос. зеленый \nкорм и сенаж
# 20                           Кормовые корнеплоды (включая сахарную свеклу на корм скоту)
# 21                                                                 Сено многолетних трав
# 22                                                                  Сено однолетних трав
# 23  Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях
#
#     1976-1980  1981-1985  1986-1990  1991-1995  1996-2000   2001   2002  \
# 0        13.8       13.0       16.5       15.7       15.1   19.4   19.6
# 1        21.6       20.1       28.5       24.3       21.3   29.1   29.9
# 2        12.2       11.0       12.3       11.7       12.7   15.7   14.4
# 3        11.1       13.0       16.7       15.9       15.0   18.8   19.0
# 4        27.8       29.0       29.8       27.6       22.4   18.0   28.5
# 5        28.4       27.9       37.3       32.3       30.4   36.3   39.4
# 6        13.9       12.2       15.6       15.7       14.7   19.0   18.3
# 7        12.2       12.3       13.8       13.6       13.6   17.1   15.6
# 8         6.3        8.1       12.9        8.1        9.0    7.9    8.5
# 9         4.0        4.1        6.2        5.2        6.0    5.4    5.4
# 10       34.5       33.7       35.4       29.2       28.2   34.9   37.7
# 11       11.1        9.9       11.9       12.4       12.9   17.9   15.9
# 12        2.5        2.9        3.2        3.8        4.0    5.0    4.7
# 13      158.0      166.0      230.0      179.0      177.0  199.0  219.0
# 14        8.4        8.3       11.8        9.9        8.4    7.9    9.8
# 15        9.9       10.0       13.3       10.5        8.5    7.8    9.7
# 16        6.5        5.7       10.6        8.8        8.4    9.4   11.7
# 17      106.0      104.0      110.0      110.0      105.0  109.0  103.0
# 18      143.0      157.0      163.0      145.0      146.0  155.0  152.0
# 19      140.0      163.0      200.0      148.0      133.0  119.0  118.0
# 20      162.0      183.0      247.0      219.0      214.0  209.0  199.0
# 21       18.5       23.3       26.3       19.8       14.3   15.8   14.8
# 22       15.8       17.1       20.0       15.6       14.4   15.6   15.8
# 23        7.6        8.5        9.4        8.5        7.7    8.0    8.0
#
#      2003   2004   2005   2006
# 0    17.8   18.8   18.5   18.9
# 1    21.2   29.4   28.3   28.0
# 2    14.8   13.8   13.0   14.3
# 3    18.6   15.5   15.7   17.1
# 4    32.0   40.3   38.5   36.2
# 5    26.3   37.4   32.4   36.3
# 6    19.1   16.8   17.3   18.0
# 7    16.8   15.1   14.4   14.7
# 8    13.9   11.9   11.2   10.4
# 9     8.2    7.5    7.3    8.1
# 10   31.5   37.7   42.0   43.9
# 11   14.8   16.2   15.4   16.0
# 12    6.6    5.8    6.3    6.1
# 13  227.0  277.0  282.0  325.0
# 14    9.9   10.2   11.7   11.2
# 15   10.0   10.2   11.9   11.4
# 16    9.8   10.0   10.5    9.9
# 17  116.0  115.0  121.0  130.0
# 18  168.0  167.0  175.0  179.0
# 19  153.0  157.0  164.0  157.0
# 20  228.0  230.0  238.0  258.0
# 21   15.2   15.7   16.4   15.6
# 22   16.2   15.7   16.4   16.3
# 23    8.0    8.0    8.4    7.6

# %% [markdown]
# ***3. Вычислить коэффициенты корреляции для каждых факторов. ***

# %%
df.corr()
# Out:
#            1976-1980  1981-1985  1986-1990  1991-1995  1996-2000      2001  \
# 1976-1980   1.000000   0.997746   0.987088   0.989628   0.987319  0.982029
# 1981-1985   0.997746   1.000000   0.990525   0.990153   0.986556  0.976441
# 1986-1990   0.987088   0.990525   1.000000   0.993784   0.990329  0.981388
# 1991-1995   0.989628   0.990153   0.993784   1.000000   0.998808  0.990507
# 1996-2000   0.987319   0.986556   0.990329   0.998808   1.000000  0.994866
# 2001        0.982029   0.976441   0.981388   0.990507   0.994866  1.000000
# 2002        0.977040   0.969700   0.978769   0.982338   0.986817  0.996222
# 2003        0.987915   0.985327   0.991093   0.993564   0.995396  0.995107
# 2004        0.974262   0.968397   0.982475   0.978084   0.980431  0.987744
# 2005        0.977635   0.972104   0.984350   0.980562   0.982769  0.989118
# 2006        0.961826   0.953543   0.971614   0.968229   0.972452  0.984198
#
#                2002      2003      2004      2005      2006
# 1976-1980  0.977040  0.987915  0.974262  0.977635  0.961826
# 1981-1985  0.969700  0.985327  0.968397  0.972104  0.953543
# 1986-1990  0.978769  0.991093  0.982475  0.984350  0.971614
# 1991-1995  0.982338  0.993564  0.978084  0.980562  0.968229
# 1996-2000  0.986817  0.995396  0.980431  0.982769  0.972452
# 2001       0.996222  0.995107  0.987744  0.989118  0.984198
# 2002       1.000000  0.994022  0.996020  0.996171  0.994364
# 2003       0.994022  1.000000  0.992986  0.994691  0.987221
# 2004       0.996020  0.992986  1.000000  0.999648  0.997979
# 2005       0.996171  0.994691  0.999648  1.000000  0.997371
# 2006       0.994364  0.987221  0.997979  0.997371  1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr());

# %% [markdown]
# ***4. Построить матрицу рассеяния.***

# %%
sns.pairplot(df)

# %% [markdown]
# ***Для указанных наборов данных провести реализацию метода главных компонент.***

# %% [markdown]
# Тетрадь является продолжением Семинара 1 Задания 1

# %%
df
# Out:
#                                                                                     type  \
# 0                                           Зерновые культуры (в весе \nпосле доработки)
# 1                                                                         пшеница озимая
# 2                                                                         пшеница яровая
# 3                                                                            рожь озимая
# 4                                                                      кукуруза на зерно
# 5                                                                          ячмень озимый
# 6                                                                          ячмень яровой
# 7                                                                                   овес
# 8                                                                                  просо
# 9                                                                                гречиха
# 10                                                                                   рис
# 11                                                                          зернобобовые
# 12                                                                Лен-долгунец (волокно)
# 13                                                           Сахарная свекла (фабричная)
# 14                                                                    Масличные культуры
# 15                                                                          подсолнечник
# 16                                                                                   соя
# 17                                                                             Картофель
# 18                                                                                 Овощи
# 19                                             Кукуруза на силос. зеленый \nкорм и сенаж
# 20                           Кормовые корнеплоды (включая сахарную свеклу на корм скоту)
# 21                                                                 Сено многолетних трав
# 22                                                                  Сено однолетних трав
# 23  Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях
#
#     1976-1980  1981-1985  1986-1990  1991-1995  1996-2000   2001   2002  \
# 0        13.8       13.0       16.5       15.7       15.1   19.4   19.6
# 1        21.6       20.1       28.5       24.3       21.3   29.1   29.9
# 2        12.2       11.0       12.3       11.7       12.7   15.7   14.4
# 3        11.1       13.0       16.7       15.9       15.0   18.8   19.0
# 4        27.8       29.0       29.8       27.6       22.4   18.0   28.5
# 5        28.4       27.9       37.3       32.3       30.4   36.3   39.4
# 6        13.9       12.2       15.6       15.7       14.7   19.0   18.3
# 7        12.2       12.3       13.8       13.6       13.6   17.1   15.6
# 8         6.3        8.1       12.9        8.1        9.0    7.9    8.5
# 9         4.0        4.1        6.2        5.2        6.0    5.4    5.4
# 10       34.5       33.7       35.4       29.2       28.2   34.9   37.7
# 11       11.1        9.9       11.9       12.4       12.9   17.9   15.9
# 12        2.5        2.9        3.2        3.8        4.0    5.0    4.7
# 13      158.0      166.0      230.0      179.0      177.0  199.0  219.0
# 14        8.4        8.3       11.8        9.9        8.4    7.9    9.8
# 15        9.9       10.0       13.3       10.5        8.5    7.8    9.7
# 16        6.5        5.7       10.6        8.8        8.4    9.4   11.7
# 17      106.0      104.0      110.0      110.0      105.0  109.0  103.0
# 18      143.0      157.0      163.0      145.0      146.0  155.0  152.0
# 19      140.0      163.0      200.0      148.0      133.0  119.0  118.0
# 20      162.0      183.0      247.0      219.0      214.0  209.0  199.0
# 21       18.5       23.3       26.3       19.8       14.3   15.8   14.8
# 22       15.8       17.1       20.0       15.6       14.4   15.6   15.8
# 23        7.6        8.5        9.4        8.5        7.7    8.0    8.0
#
#      2003   2004   2005   2006
# 0    17.8   18.8   18.5   18.9
# 1    21.2   29.4   28.3   28.0
# 2    14.8   13.8   13.0   14.3
# 3    18.6   15.5   15.7   17.1
# 4    32.0   40.3   38.5   36.2
# 5    26.3   37.4   32.4   36.3
# 6    19.1   16.8   17.3   18.0
# 7    16.8   15.1   14.4   14.7
# 8    13.9   11.9   11.2   10.4
# 9     8.2    7.5    7.3    8.1
# 10   31.5   37.7   42.0   43.9
# 11   14.8   16.2   15.4   16.0
# 12    6.6    5.8    6.3    6.1
# 13  227.0  277.0  282.0  325.0
# 14    9.9   10.2   11.7   11.2
# 15   10.0   10.2   11.9   11.4
# 16    9.8   10.0   10.5    9.9
# 17  116.0  115.0  121.0  130.0
# 18  168.0  167.0  175.0  179.0
# 19  153.0  157.0  164.0  157.0
# 20  228.0  230.0  238.0  258.0
# 21   15.2   15.7   16.4   15.6
# 22   16.2   15.7   16.4   16.3
# 23    8.0    8.0    8.4    7.6

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
df2 = df.drop('type', axis=1)

# %%
df2.corr()
# Out:
#            1976-1980  1981-1985  1986-1990  1991-1995  1996-2000      2001  \
# 1976-1980   1.000000   0.997746   0.987088   0.989628   0.987319  0.982029
# 1981-1985   0.997746   1.000000   0.990525   0.990153   0.986556  0.976441
# 1986-1990   0.987088   0.990525   1.000000   0.993784   0.990329  0.981388
# 1991-1995   0.989628   0.990153   0.993784   1.000000   0.998808  0.990507
# 1996-2000   0.987319   0.986556   0.990329   0.998808   1.000000  0.994866
# 2001        0.982029   0.976441   0.981388   0.990507   0.994866  1.000000
# 2002        0.977040   0.969700   0.978769   0.982338   0.986817  0.996222
# 2003        0.987915   0.985327   0.991093   0.993564   0.995396  0.995107
# 2004        0.974262   0.968397   0.982475   0.978084   0.980431  0.987744
# 2005        0.977635   0.972104   0.984350   0.980562   0.982769  0.989118
# 2006        0.961826   0.953543   0.971614   0.968229   0.972452  0.984198
#
#                2002      2003      2004      2005      2006
# 1976-1980  0.977040  0.987915  0.974262  0.977635  0.961826
# 1981-1985  0.969700  0.985327  0.968397  0.972104  0.953543
# 1986-1990  0.978769  0.991093  0.982475  0.984350  0.971614
# 1991-1995  0.982338  0.993564  0.978084  0.980562  0.968229
# 1996-2000  0.986817  0.995396  0.980431  0.982769  0.972452
# 2001       0.996222  0.995107  0.987744  0.989118  0.984198
# 2002       1.000000  0.994022  0.996020  0.996171  0.994364
# 2003       0.994022  1.000000  0.992986  0.994691  0.987221
# 2004       0.996020  0.992986  1.000000  0.999648  0.997979
# 2005       0.996171  0.994691  0.999648  1.000000  0.997371
# 2006       0.994364  0.987221  0.997979  0.997371  1.000000

# %%
df2_scaled = df2.copy()
df2_scaled= sc.fit_transform(df2_scaled)
df2_scaled = pd.DataFrame(df2_scaled, columns = df2.columns)

# %%
df2_scaled
# Out:
#     1976-1980  1981-1985  1986-1990  1991-1995  1996-2000      2001      2002  \
# 0   -0.504174  -0.518130  -0.498264  -0.481974  -0.471429 -0.432921 -0.438987
# 1   -0.357596  -0.397368  -0.336208  -0.342413  -0.368209 -0.274056 -0.271340
# 2   -0.534241  -0.552147  -0.554983  -0.546887  -0.511386 -0.493519 -0.523624
# 3   -0.554912  -0.518130  -0.495563  -0.478729  -0.473094 -0.442748 -0.448753
# 4   -0.241086  -0.245989  -0.318652  -0.288860  -0.349895 -0.455850 -0.294127
# 5   -0.229810  -0.264699  -0.217368  -0.212588  -0.216708 -0.156135 -0.116715
# 6   -0.502294  -0.531737  -0.510418  -0.481974  -0.478089 -0.439472 -0.460146
# 7   -0.534241  -0.530036  -0.534726  -0.516053  -0.496402 -0.470590 -0.504092
# 8   -0.645114  -0.601473  -0.546880  -0.605308  -0.572985 -0.621266 -0.619654
# 9   -0.688335  -0.669508  -0.637361  -0.652369  -0.622930 -0.662211 -0.670111
# 10  -0.115179  -0.166048  -0.243027  -0.262895  -0.253334 -0.179064 -0.144385
# 11  -0.554912  -0.570857  -0.560385  -0.535527  -0.508056 -0.457488 -0.499209
# 12  -0.716523  -0.689919  -0.677875  -0.675088  -0.656227 -0.668762 -0.681505
# 13   2.205632   2.084213   2.384970   2.168073   2.223958  2.508541  2.806518
# 14  -0.605650  -0.598071  -0.561735  -0.576097  -0.582974 -0.621266 -0.598495
# 15  -0.577462  -0.569156  -0.541478  -0.566360  -0.581309 -0.622904 -0.600123
# 16  -0.641355  -0.642294  -0.577941  -0.593948  -0.582974 -0.596700 -0.567570
# 17   1.228449   1.029669   0.764417   1.048334   1.025268  1.034534  0.918461
# 18   1.923753   1.931134   1.480161   1.616318   1.707856  1.787915  1.716003
# 19   1.867377   2.033187   1.979831   1.665002   1.491426  1.198313  1.162607
# 20   2.280800   2.373363   2.614548   2.817196   2.839952  2.672319  2.480991
# 21  -0.415851  -0.342940  -0.365919  -0.415439  -0.484748 -0.491881 -0.517113
# 22  -0.466590  -0.448394  -0.450998  -0.483597  -0.483083 -0.495157 -0.500837
# 23  -0.620684  -0.594669  -0.594146  -0.598816  -0.594628 -0.619629 -0.627793
#
#         2003      2004      2005      2006
# 0  -0.468034 -0.461772 -0.468802 -0.458382
# 1  -0.418786 -0.320372 -0.342296 -0.351358
# 2  -0.511488 -0.528469 -0.539800 -0.512483
# 3  -0.456446 -0.505792 -0.504946 -0.479552
# 4  -0.262352 -0.174971 -0.210627 -0.254918
# 5  -0.344915 -0.213656 -0.289371 -0.253742
# 6  -0.449204 -0.488451 -0.484292 -0.468967
# 7  -0.482519 -0.511128 -0.521727 -0.507778
# 8  -0.524524 -0.553815 -0.563035 -0.558350
# 9  -0.607086 -0.612509 -0.613379 -0.585400
# 10 -0.269595 -0.209654 -0.165447 -0.164359
# 11 -0.511488 -0.496454 -0.508819 -0.492489
# 12 -0.630262 -0.635186 -0.626288 -0.608922
# 13  2.562146  2.982506  2.932646  3.141638
# 14 -0.582462 -0.576492 -0.556581 -0.548941
# 15 -0.581014 -0.576492 -0.553999 -0.546589
# 16 -0.583911 -0.579160 -0.572071 -0.564231
# 17  0.954355  0.821495  0.854342  0.848257
# 18  1.707554  1.515153  1.551413  1.424543
# 19  1.490285  1.381758  1.409417  1.165802
# 20  2.576631  2.355546  2.364663  2.353656
# 21 -0.505694 -0.503124 -0.495910 -0.497193
# 22 -0.491209 -0.503124 -0.495910 -0.488961
# 23 -0.609983 -0.605839 -0.599180 -0.591281

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)
pca.fit(df2_scaled)
print(pca.explained_variance_ratio_)
# Out:
# [0.9867342  0.00886846 0.00238991]

# %%
pca = PCA(n_components=1)
pca.fit(df2_scaled)
print(pca.explained_variance_ratio_)
# Out:
# [0.9867342]

# %% [markdown]
# ***Факторный анализ***

# %%
from sklearn.decomposition import FactorAnalysis

fa = FactorAnalysis(n_components=1)
fa.fit(df2_scaled)
# Out:
# FactorAnalysis(copy=True, iterated_power=3, max_iter=1000, n_components=1,
#                noise_variance_init=None, random_state=0,
#                svd_method='randomized', tol=0.01)

# %%
pd.DataFrame(fa.components_, columns=df2.columns)
# Out:
#    1976-1980  1981-1985  1986-1990  1991-1995  1996-2000      2001      2002  \
# 0   0.988149   0.985278   0.991334   0.993754   0.995468  0.995667  0.994733
#
#        2003      2004      2005      2006
# 0  0.999646  0.993321  0.994895  0.987606

# %%
print('Uniqueness:')
pd.Series(fa.noise_variance_, df2.columns)
# Out:
# Uniqueness:
# 1976-1980    0.023563
# 1981-1985    0.029241
# 1986-1990    0.017257
# 1991-1995    0.012455
# 1996-2000    0.009048
# 2001         0.008626
# 2002         0.010478
# 2003         0.000726
# 2004         0.013299
# 2005         0.010176
# 2006         0.024616
# dtype: float64

# %%
df
# Out:
#                                                                                     type  \
# 0                                           Зерновые культуры (в весе \nпосле доработки)
# 1                                                                         пшеница озимая
# 2                                                                         пшеница яровая
# 3                                                                            рожь озимая
# 4                                                                      кукуруза на зерно
# 5                                                                          ячмень озимый
# 6                                                                          ячмень яровой
# 7                                                                                   овес
# 8                                                                                  просо
# 9                                                                                гречиха
# 10                                                                                   рис
# 11                                                                          зернобобовые
# 12                                                                Лен-долгунец (волокно)
# 13                                                           Сахарная свекла (фабричная)
# 14                                                                    Масличные культуры
# 15                                                                          подсолнечник
# 16                                                                                   соя
# 17                                                                             Картофель
# 18                                                                                 Овощи
# 19                                             Кукуруза на силос. зеленый \nкорм и сенаж
# 20                           Кормовые корнеплоды (включая сахарную свеклу на корм скоту)
# 21                                                                 Сено многолетних трав
# 22                                                                  Сено однолетних трав
# 23  Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях
#
#     1976-1980  1981-1985  1986-1990  1991-1995  1996-2000   2001   2002  \
# 0        13.8       13.0       16.5       15.7       15.1   19.4   19.6
# 1        21.6       20.1       28.5       24.3       21.3   29.1   29.9
# 2        12.2       11.0       12.3       11.7       12.7   15.7   14.4
# 3        11.1       13.0       16.7       15.9       15.0   18.8   19.0
# 4        27.8       29.0       29.8       27.6       22.4   18.0   28.5
# 5        28.4       27.9       37.3       32.3       30.4   36.3   39.4
# 6        13.9       12.2       15.6       15.7       14.7   19.0   18.3
# 7        12.2       12.3       13.8       13.6       13.6   17.1   15.6
# 8         6.3        8.1       12.9        8.1        9.0    7.9    8.5
# 9         4.0        4.1        6.2        5.2        6.0    5.4    5.4
# 10       34.5       33.7       35.4       29.2       28.2   34.9   37.7
# 11       11.1        9.9       11.9       12.4       12.9   17.9   15.9
# 12        2.5        2.9        3.2        3.8        4.0    5.0    4.7
# 13      158.0      166.0      230.0      179.0      177.0  199.0  219.0
# 14        8.4        8.3       11.8        9.9        8.4    7.9    9.8
# 15        9.9       10.0       13.3       10.5        8.5    7.8    9.7
# 16        6.5        5.7       10.6        8.8        8.4    9.4   11.7
# 17      106.0      104.0      110.0      110.0      105.0  109.0  103.0
# 18      143.0      157.0      163.0      145.0      146.0  155.0  152.0
# 19      140.0      163.0      200.0      148.0      133.0  119.0  118.0
# 20      162.0      183.0      247.0      219.0      214.0  209.0  199.0
# 21       18.5       23.3       26.3       19.8       14.3   15.8   14.8
# 22       15.8       17.1       20.0       15.6       14.4   15.6   15.8
# 23        7.6        8.5        9.4        8.5        7.7    8.0    8.0
#
#      2003   2004   2005   2006
# 0    17.8   18.8   18.5   18.9
# 1    21.2   29.4   28.3   28.0
# 2    14.8   13.8   13.0   14.3
# 3    18.6   15.5   15.7   17.1
# 4    32.0   40.3   38.5   36.2
# 5    26.3   37.4   32.4   36.3
# 6    19.1   16.8   17.3   18.0
# 7    16.8   15.1   14.4   14.7
# 8    13.9   11.9   11.2   10.4
# 9     8.2    7.5    7.3    8.1
# 10   31.5   37.7   42.0   43.9
# 11   14.8   16.2   15.4   16.0
# 12    6.6    5.8    6.3    6.1
# 13  227.0  277.0  282.0  325.0
# 14    9.9   10.2   11.7   11.2
# 15   10.0   10.2   11.9   11.4
# 16    9.8   10.0   10.5    9.9
# 17  116.0  115.0  121.0  130.0
# 18  168.0  167.0  175.0  179.0
# 19  153.0  157.0  164.0  157.0
# 20  228.0  230.0  238.0  258.0
# 21   15.2   15.7   16.4   15.6
# 22   16.2   15.7   16.4   16.3
# 23    8.0    8.0    8.4    7.6

# %%
df.set_index('type', inplace=True)
df
# Out:
#                                                                                       1976-1980  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               13.8
#   пшеница озимая                                                                           21.6
#   пшеница яровая                                                                           12.2
#   рожь озимая                                                                              11.1
#   кукуруза на зерно                                                                        27.8
#   ячмень озимый                                                                            28.4
#   ячмень яровой                                                                            13.9
#   овес                                                                                     12.2
#   просо                                                                                     6.3
#   гречиха                                                                                   4.0
#   рис                                                                                      34.5
#   зернобобовые                                                                             11.1
# Лен-долгунец (волокно)                                                                      2.5
# Сахарная свекла (фабричная)                                                               158.0
# Масличные культуры                                                                          8.4
#   подсолнечник                                                                              9.9
#   соя                                                                                       6.5
# Картофель                                                                                 106.0
# Овощи                                                                                     143.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 140.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               162.0
# Сено многолетних трав                                                                      18.5
# Сено однолетних трав                                                                       15.8
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        7.6
#
#                                                                                       1981-1985  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               13.0
#   пшеница озимая                                                                           20.1
#   пшеница яровая                                                                           11.0
#   рожь озимая                                                                              13.0
#   кукуруза на зерно                                                                        29.0
#   ячмень озимый                                                                            27.9
#   ячмень яровой                                                                            12.2
#   овес                                                                                     12.3
#   просо                                                                                     8.1
#   гречиха                                                                                   4.1
#   рис                                                                                      33.7
#   зернобобовые                                                                              9.9
# Лен-долгунец (волокно)                                                                      2.9
# Сахарная свекла (фабричная)                                                               166.0
# Масличные культуры                                                                          8.3
#   подсолнечник                                                                             10.0
#   соя                                                                                       5.7
# Картофель                                                                                 104.0
# Овощи                                                                                     157.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 163.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               183.0
# Сено многолетних трав                                                                      23.3
# Сено однолетних трав                                                                       17.1
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        8.5
#
#                                                                                       1986-1990  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               16.5
#   пшеница озимая                                                                           28.5
#   пшеница яровая                                                                           12.3
#   рожь озимая                                                                              16.7
#   кукуруза на зерно                                                                        29.8
#   ячмень озимый                                                                            37.3
#   ячмень яровой                                                                            15.6
#   овес                                                                                     13.8
#   просо                                                                                    12.9
#   гречиха                                                                                   6.2
#   рис                                                                                      35.4
#   зернобобовые                                                                             11.9
# Лен-долгунец (волокно)                                                                      3.2
# Сахарная свекла (фабричная)                                                               230.0
# Масличные культуры                                                                         11.8
#   подсолнечник                                                                             13.3
#   соя                                                                                      10.6
# Картофель                                                                                 110.0
# Овощи                                                                                     163.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 200.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               247.0
# Сено многолетних трав                                                                      26.3
# Сено однолетних трав                                                                       20.0
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        9.4
#
#                                                                                       1991-1995  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               15.7
#   пшеница озимая                                                                           24.3
#   пшеница яровая                                                                           11.7
#   рожь озимая                                                                              15.9
#   кукуруза на зерно                                                                        27.6
#   ячмень озимый                                                                            32.3
#   ячмень яровой                                                                            15.7
#   овес                                                                                     13.6
#   просо                                                                                     8.1
#   гречиха                                                                                   5.2
#   рис                                                                                      29.2
#   зернобобовые                                                                             12.4
# Лен-долгунец (волокно)                                                                      3.8
# Сахарная свекла (фабричная)                                                               179.0
# Масличные культуры                                                                          9.9
#   подсолнечник                                                                             10.5
#   соя                                                                                       8.8
# Картофель                                                                                 110.0
# Овощи                                                                                     145.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 148.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               219.0
# Сено многолетних трав                                                                      19.8
# Сено однолетних трав                                                                       15.6
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        8.5
#
#                                                                                       1996-2000  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               15.1
#   пшеница озимая                                                                           21.3
#   пшеница яровая                                                                           12.7
#   рожь озимая                                                                              15.0
#   кукуруза на зерно                                                                        22.4
#   ячмень озимый                                                                            30.4
#   ячмень яровой                                                                            14.7
#   овес                                                                                     13.6
#   просо                                                                                     9.0
#   гречиха                                                                                   6.0
#   рис                                                                                      28.2
#   зернобобовые                                                                             12.9
# Лен-долгунец (волокно)                                                                      4.0
# Сахарная свекла (фабричная)                                                               177.0
# Масличные культуры                                                                          8.4
#   подсолнечник                                                                              8.5
#   соя                                                                                       8.4
# Картофель                                                                                 105.0
# Овощи                                                                                     146.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 133.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               214.0
# Сено многолетних трав                                                                      14.3
# Сено однолетних трав                                                                       14.4
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        7.7
#
#                                                                                        2001  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           19.4
#   пшеница озимая                                                                       29.1
#   пшеница яровая                                                                       15.7
#   рожь озимая                                                                          18.8
#   кукуруза на зерно                                                                    18.0
#   ячмень озимый                                                                        36.3
#   ячмень яровой                                                                        19.0
#   овес                                                                                 17.1
#   просо                                                                                 7.9
#   гречиха                                                                               5.4
#   рис                                                                                  34.9
#   зернобобовые                                                                         17.9
# Лен-долгунец (волокно)                                                                  5.0
# Сахарная свекла (фабричная)                                                           199.0
# Масличные культуры                                                                      7.9
#   подсолнечник                                                                          7.8
#   соя                                                                                   9.4
# Картофель                                                                             109.0
# Овощи                                                                                 155.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             119.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           209.0
# Сено многолетних трав                                                                  15.8
# Сено однолетних трав                                                                   15.6
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.0
#
#                                                                                        2002  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           19.6
#   пшеница озимая                                                                       29.9
#   пшеница яровая                                                                       14.4
#   рожь озимая                                                                          19.0
#   кукуруза на зерно                                                                    28.5
#   ячмень озимый                                                                        39.4
#   ячмень яровой                                                                        18.3
#   овес                                                                                 15.6
#   просо                                                                                 8.5
#   гречиха                                                                               5.4
#   рис                                                                                  37.7
#   зернобобовые                                                                         15.9
# Лен-долгунец (волокно)                                                                  4.7
# Сахарная свекла (фабричная)                                                           219.0
# Масличные культуры                                                                      9.8
#   подсолнечник                                                                          9.7
#   соя                                                                                  11.7
# Картофель                                                                             103.0
# Овощи                                                                                 152.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             118.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           199.0
# Сено многолетних трав                                                                  14.8
# Сено однолетних трав                                                                   15.8
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.0
#
#                                                                                        2003  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           17.8
#   пшеница озимая                                                                       21.2
#   пшеница яровая                                                                       14.8
#   рожь озимая                                                                          18.6
#   кукуруза на зерно                                                                    32.0
#   ячмень озимый                                                                        26.3
#   ячмень яровой                                                                        19.1
#   овес                                                                                 16.8
#   просо                                                                                13.9
#   гречиха                                                                               8.2
#   рис                                                                                  31.5
#   зернобобовые                                                                         14.8
# Лен-долгунец (волокно)                                                                  6.6
# Сахарная свекла (фабричная)                                                           227.0
# Масличные культуры                                                                      9.9
#   подсолнечник                                                                         10.0
#   соя                                                                                   9.8
# Картофель                                                                             116.0
# Овощи                                                                                 168.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             153.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           228.0
# Сено многолетних трав                                                                  15.2
# Сено однолетних трав                                                                   16.2
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.0
#
#                                                                                        2004  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           18.8
#   пшеница озимая                                                                       29.4
#   пшеница яровая                                                                       13.8
#   рожь озимая                                                                          15.5
#   кукуруза на зерно                                                                    40.3
#   ячмень озимый                                                                        37.4
#   ячмень яровой                                                                        16.8
#   овес                                                                                 15.1
#   просо                                                                                11.9
#   гречиха                                                                               7.5
#   рис                                                                                  37.7
#   зернобобовые                                                                         16.2
# Лен-долгунец (волокно)                                                                  5.8
# Сахарная свекла (фабричная)                                                           277.0
# Масличные культуры                                                                     10.2
#   подсолнечник                                                                         10.2
#   соя                                                                                  10.0
# Картофель                                                                             115.0
# Овощи                                                                                 167.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             157.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           230.0
# Сено многолетних трав                                                                  15.7
# Сено однолетних трав                                                                   15.7
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.0
#
#                                                                                        2005  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           18.5
#   пшеница озимая                                                                       28.3
#   пшеница яровая                                                                       13.0
#   рожь озимая                                                                          15.7
#   кукуруза на зерно                                                                    38.5
#   ячмень озимый                                                                        32.4
#   ячмень яровой                                                                        17.3
#   овес                                                                                 14.4
#   просо                                                                                11.2
#   гречиха                                                                               7.3
#   рис                                                                                  42.0
#   зернобобовые                                                                         15.4
# Лен-долгунец (волокно)                                                                  6.3
# Сахарная свекла (фабричная)                                                           282.0
# Масличные культуры                                                                     11.7
#   подсолнечник                                                                         11.9
#   соя                                                                                  10.5
# Картофель                                                                             121.0
# Овощи                                                                                 175.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             164.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           238.0
# Сено многолетних трав                                                                  16.4
# Сено однолетних трав                                                                   16.4
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.4
#
#                                                                                        2006
# type
# Зерновые культуры (в весе \nпосле доработки)                                           18.9
#   пшеница озимая                                                                       28.0
#   пшеница яровая                                                                       14.3
#   рожь озимая                                                                          17.1
#   кукуруза на зерно                                                                    36.2
#   ячмень озимый                                                                        36.3
#   ячмень яровой                                                                        18.0
#   овес                                                                                 14.7
#   просо                                                                                10.4
#   гречиха                                                                               8.1
#   рис                                                                                  43.9
#   зернобобовые                                                                         16.0
# Лен-долгунец (волокно)                                                                  6.1
# Сахарная свекла (фабричная)                                                           325.0
# Масличные культуры                                                                     11.2
#   подсолнечник                                                                         11.4
#   соя                                                                                   9.9
# Картофель                                                                             130.0
# Овощи                                                                                 179.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             157.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           258.0
# Сено многолетних трав                                                                  15.6
# Сено однолетних трав                                                                   16.3
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    7.6

# %% [markdown]
# ***K-Means***

# %% [markdown]
# ***тетрадь является продолжением предыдущей***

# %% [markdown]
# установили имя как индекс

# %%
df
# Out:
#                                                                                       1976-1980  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               13.8
#   пшеница озимая                                                                           21.6
#   пшеница яровая                                                                           12.2
#   рожь озимая                                                                              11.1
#   кукуруза на зерно                                                                        27.8
#   ячмень озимый                                                                            28.4
#   ячмень яровой                                                                            13.9
#   овес                                                                                     12.2
#   просо                                                                                     6.3
#   гречиха                                                                                   4.0
#   рис                                                                                      34.5
#   зернобобовые                                                                             11.1
# Лен-долгунец (волокно)                                                                      2.5
# Сахарная свекла (фабричная)                                                               158.0
# Масличные культуры                                                                          8.4
#   подсолнечник                                                                              9.9
#   соя                                                                                       6.5
# Картофель                                                                                 106.0
# Овощи                                                                                     143.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 140.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               162.0
# Сено многолетних трав                                                                      18.5
# Сено однолетних трав                                                                       15.8
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        7.6
#
#                                                                                       1981-1985  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               13.0
#   пшеница озимая                                                                           20.1
#   пшеница яровая                                                                           11.0
#   рожь озимая                                                                              13.0
#   кукуруза на зерно                                                                        29.0
#   ячмень озимый                                                                            27.9
#   ячмень яровой                                                                            12.2
#   овес                                                                                     12.3
#   просо                                                                                     8.1
#   гречиха                                                                                   4.1
#   рис                                                                                      33.7
#   зернобобовые                                                                              9.9
# Лен-долгунец (волокно)                                                                      2.9
# Сахарная свекла (фабричная)                                                               166.0
# Масличные культуры                                                                          8.3
#   подсолнечник                                                                             10.0
#   соя                                                                                       5.7
# Картофель                                                                                 104.0
# Овощи                                                                                     157.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 163.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               183.0
# Сено многолетних трав                                                                      23.3
# Сено однолетних трав                                                                       17.1
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        8.5
#
#                                                                                       1986-1990  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               16.5
#   пшеница озимая                                                                           28.5
#   пшеница яровая                                                                           12.3
#   рожь озимая                                                                              16.7
#   кукуруза на зерно                                                                        29.8
#   ячмень озимый                                                                            37.3
#   ячмень яровой                                                                            15.6
#   овес                                                                                     13.8
#   просо                                                                                    12.9
#   гречиха                                                                                   6.2
#   рис                                                                                      35.4
#   зернобобовые                                                                             11.9
# Лен-долгунец (волокно)                                                                      3.2
# Сахарная свекла (фабричная)                                                               230.0
# Масличные культуры                                                                         11.8
#   подсолнечник                                                                             13.3
#   соя                                                                                      10.6
# Картофель                                                                                 110.0
# Овощи                                                                                     163.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 200.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               247.0
# Сено многолетних трав                                                                      26.3
# Сено однолетних трав                                                                       20.0
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        9.4
#
#                                                                                       1991-1995  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               15.7
#   пшеница озимая                                                                           24.3
#   пшеница яровая                                                                           11.7
#   рожь озимая                                                                              15.9
#   кукуруза на зерно                                                                        27.6
#   ячмень озимый                                                                            32.3
#   ячмень яровой                                                                            15.7
#   овес                                                                                     13.6
#   просо                                                                                     8.1
#   гречиха                                                                                   5.2
#   рис                                                                                      29.2
#   зернобобовые                                                                             12.4
# Лен-долгунец (волокно)                                                                      3.8
# Сахарная свекла (фабричная)                                                               179.0
# Масличные культуры                                                                          9.9
#   подсолнечник                                                                             10.5
#   соя                                                                                       8.8
# Картофель                                                                                 110.0
# Овощи                                                                                     145.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 148.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               219.0
# Сено многолетних трав                                                                      19.8
# Сено однолетних трав                                                                       15.6
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        8.5
#
#                                                                                       1996-2000  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                               15.1
#   пшеница озимая                                                                           21.3
#   пшеница яровая                                                                           12.7
#   рожь озимая                                                                              15.0
#   кукуруза на зерно                                                                        22.4
#   ячмень озимый                                                                            30.4
#   ячмень яровой                                                                            14.7
#   овес                                                                                     13.6
#   просо                                                                                     9.0
#   гречиха                                                                                   6.0
#   рис                                                                                      28.2
#   зернобобовые                                                                             12.9
# Лен-долгунец (волокно)                                                                      4.0
# Сахарная свекла (фабричная)                                                               177.0
# Масличные культуры                                                                          8.4
#   подсолнечник                                                                              8.5
#   соя                                                                                       8.4
# Картофель                                                                                 105.0
# Овощи                                                                                     146.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                                 133.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                               214.0
# Сено многолетних трав                                                                      14.3
# Сено однолетних трав                                                                       14.4
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях        7.7
#
#                                                                                        2001  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           19.4
#   пшеница озимая                                                                       29.1
#   пшеница яровая                                                                       15.7
#   рожь озимая                                                                          18.8
#   кукуруза на зерно                                                                    18.0
#   ячмень озимый                                                                        36.3
#   ячмень яровой                                                                        19.0
#   овес                                                                                 17.1
#   просо                                                                                 7.9
#   гречиха                                                                               5.4
#   рис                                                                                  34.9
#   зернобобовые                                                                         17.9
# Лен-долгунец (волокно)                                                                  5.0
# Сахарная свекла (фабричная)                                                           199.0
# Масличные культуры                                                                      7.9
#   подсолнечник                                                                          7.8
#   соя                                                                                   9.4
# Картофель                                                                             109.0
# Овощи                                                                                 155.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             119.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           209.0
# Сено многолетних трав                                                                  15.8
# Сено однолетних трав                                                                   15.6
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.0
#
#                                                                                        2002  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           19.6
#   пшеница озимая                                                                       29.9
#   пшеница яровая                                                                       14.4
#   рожь озимая                                                                          19.0
#   кукуруза на зерно                                                                    28.5
#   ячмень озимый                                                                        39.4
#   ячмень яровой                                                                        18.3
#   овес                                                                                 15.6
#   просо                                                                                 8.5
#   гречиха                                                                               5.4
#   рис                                                                                  37.7
#   зернобобовые                                                                         15.9
# Лен-долгунец (волокно)                                                                  4.7
# Сахарная свекла (фабричная)                                                           219.0
# Масличные культуры                                                                      9.8
#   подсолнечник                                                                          9.7
#   соя                                                                                  11.7
# Картофель                                                                             103.0
# Овощи                                                                                 152.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             118.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           199.0
# Сено многолетних трав                                                                  14.8
# Сено однолетних трав                                                                   15.8
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.0
#
#                                                                                        2003  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           17.8
#   пшеница озимая                                                                       21.2
#   пшеница яровая                                                                       14.8
#   рожь озимая                                                                          18.6
#   кукуруза на зерно                                                                    32.0
#   ячмень озимый                                                                        26.3
#   ячмень яровой                                                                        19.1
#   овес                                                                                 16.8
#   просо                                                                                13.9
#   гречиха                                                                               8.2
#   рис                                                                                  31.5
#   зернобобовые                                                                         14.8
# Лен-долгунец (волокно)                                                                  6.6
# Сахарная свекла (фабричная)                                                           227.0
# Масличные культуры                                                                      9.9
#   подсолнечник                                                                         10.0
#   соя                                                                                   9.8
# Картофель                                                                             116.0
# Овощи                                                                                 168.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             153.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           228.0
# Сено многолетних трав                                                                  15.2
# Сено однолетних трав                                                                   16.2
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.0
#
#                                                                                        2004  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           18.8
#   пшеница озимая                                                                       29.4
#   пшеница яровая                                                                       13.8
#   рожь озимая                                                                          15.5
#   кукуруза на зерно                                                                    40.3
#   ячмень озимый                                                                        37.4
#   ячмень яровой                                                                        16.8
#   овес                                                                                 15.1
#   просо                                                                                11.9
#   гречиха                                                                               7.5
#   рис                                                                                  37.7
#   зернобобовые                                                                         16.2
# Лен-долгунец (волокно)                                                                  5.8
# Сахарная свекла (фабричная)                                                           277.0
# Масличные культуры                                                                     10.2
#   подсолнечник                                                                         10.2
#   соя                                                                                  10.0
# Картофель                                                                             115.0
# Овощи                                                                                 167.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             157.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           230.0
# Сено многолетних трав                                                                  15.7
# Сено однолетних трав                                                                   15.7
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.0
#
#                                                                                        2005  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                           18.5
#   пшеница озимая                                                                       28.3
#   пшеница яровая                                                                       13.0
#   рожь озимая                                                                          15.7
#   кукуруза на зерно                                                                    38.5
#   ячмень озимый                                                                        32.4
#   ячмень яровой                                                                        17.3
#   овес                                                                                 14.4
#   просо                                                                                11.2
#   гречиха                                                                               7.3
#   рис                                                                                  42.0
#   зернобобовые                                                                         15.4
# Лен-долгунец (волокно)                                                                  6.3
# Сахарная свекла (фабричная)                                                           282.0
# Масличные культуры                                                                     11.7
#   подсолнечник                                                                         11.9
#   соя                                                                                  10.5
# Картофель                                                                             121.0
# Овощи                                                                                 175.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             164.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           238.0
# Сено многолетних трав                                                                  16.4
# Сено однолетних трав                                                                   16.4
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    8.4
#
#                                                                                        2006
# type
# Зерновые культуры (в весе \nпосле доработки)                                           18.9
#   пшеница озимая                                                                       28.0
#   пшеница яровая                                                                       14.3
#   рожь озимая                                                                          17.1
#   кукуруза на зерно                                                                    36.2
#   ячмень озимый                                                                        36.3
#   ячмень яровой                                                                        18.0
#   овес                                                                                 14.7
#   просо                                                                                10.4
#   гречиха                                                                               8.1
#   рис                                                                                  43.9
#   зернобобовые                                                                         16.0
# Лен-долгунец (волокно)                                                                  6.1
# Сахарная свекла (фабричная)                                                           325.0
# Масличные культуры                                                                     11.2
#   подсолнечник                                                                         11.4
#   соя                                                                                   9.9
# Картофель                                                                             130.0
# Овощи                                                                                 179.0
# Кукуруза на силос. зеленый \nкорм и сенаж                                             157.0
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           258.0
# Сено многолетних трав                                                                  15.6
# Сено однолетних трав                                                                   16.3
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    7.6

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
df_scaled = sc.fit_transform(df)

# %%
from sklearn.cluster import KMeans

# %%
K = range(1, 11)
models = [KMeans(n_clusters=k, random_state=42).fit(df_scaled) for k in K]
dist = [model.inertia_ for model in models]

# Plot the elbow
plt.plot(K, dist, marker='o')
plt.xlabel('k')
plt.ylabel('Sum of distances')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
model = KMeans(n_clusters=2, random_state=42)
model.fit(df)
df['cluster'] = model.labels_
df.groupby('cluster').mean()
# Out:
#           1976-1980   1981-1985   1986-1990   1991-1995   1996-2000  \
# cluster
# 0         14.005263   14.215789   17.447368   15.189474   14.052632
# 1        141.800000  154.600000  190.000000  160.200000  155.000000
#
#                2001        2002        2003        2004        2005  \
# cluster
# 0         16.263158   17.194737   16.352632   17.684211   17.663158
# 1        158.200000  158.200000  178.400000  189.200000  196.000000
#
#                2006
# cluster
# 0         17.894737
# 1        209.800000

# %%
df.groupby('cluster').size()
# Out:
# cluster
# 0    19
# 1     5
# dtype: int64

# %%
df['cluster'].sort_values()
# Out:
# type
# Зерновые культуры (в весе \nпосле доработки)                                            0
# Сено многолетних трав                                                                   0
#   соя                                                                                   0
#   подсолнечник                                                                          0
# Масличные культуры                                                                      0
# Лен-долгунец (волокно)                                                                  0
# Сено однолетних трав                                                                    0
#   рис                                                                                   0
#   гречиха                                                                               0
#   зернобобовые                                                                          0
#   овес                                                                                  0
#   ячмень яровой                                                                         0
#   ячмень озимый                                                                         0
#   кукуруза на зерно                                                                     0
#   рожь озимая                                                                           0
#   пшеница яровая                                                                        0
#   пшеница озимая                                                                        0
#   просо                                                                                 0
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    0
# Сахарная свекла (фабричная)                                                             1
# Картофель                                                                               1
# Овощи                                                                                   1
# Кукуруза на силос. зеленый \nкорм и сенаж                                               1
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                             1
# Name: cluster, dtype: int32

# %% [markdown]
# ***Иерархическая кластеризация данных***

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# Объект, в котором будет хранится информация о последовательном слиянии кластеров
link = linkage(df, 'ward', 'euclidean')

# %%
dn = dendrogram(link, orientation = "right")

# %%
df['cluster'] = fcluster(link, 2, criterion='maxclust')

# %%
df.groupby('cluster').mean()
# Out:
#           1976-1980   1981-1985   1986-1990   1991-1995   1996-2000  \
# cluster
# 1         14.005263   14.215789   17.447368   15.189474   14.052632
# 2        141.800000  154.600000  190.000000  160.200000  155.000000
#
#                2001        2002        2003        2004        2005  \
# cluster
# 1         16.263158   17.194737   16.352632   17.684211   17.663158
# 2        158.200000  158.200000  178.400000  189.200000  196.000000
#
#                2006
# cluster
# 1         17.894737
# 2        209.800000

# %%
df.groupby('cluster').size()
# Out:
# cluster
# 1    19
# 2     5
# dtype: int64

# %%
dist_rev = dist[::-1]
idxs = range(1, len(dist) + 1)
plt.plot(idxs, dist_rev, marker='o')
plt.title('Distance between merged clusters')
plt.xlabel('Step')
plt.ylabel('Distance')
#plt.axhline(3, c='k', linestyle='dashed')
#plt.axhline(2.52, c='k', linestyle='dashed')
#plt.text(25, 3.1, '3 clusters')
#plt.text(22, 2.6, '4 clusters')
# Out:
# Text(0, 0.5, 'Distance')

# %%
del df['cluster']
df_scaled = pd.DataFrame(df_scaled, index=df.index, columns=df.columns)

# %%
df_scaled
# Out:
#                                                                                       1976-1980  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                          -0.504174
#   пшеница озимая                                                                      -0.357596
#   пшеница яровая                                                                      -0.534241
#   рожь озимая                                                                         -0.554912
#   кукуруза на зерно                                                                   -0.241086
#   ячмень озимый                                                                       -0.229810
#   ячмень яровой                                                                       -0.502294
#   овес                                                                                -0.534241
#   просо                                                                               -0.645114
#   гречиха                                                                             -0.688335
#   рис                                                                                 -0.115179
#   зернобобовые                                                                        -0.554912
# Лен-долгунец (волокно)                                                                -0.716523
# Сахарная свекла (фабричная)                                                            2.205632
# Масличные культуры                                                                    -0.605650
#   подсолнечник                                                                        -0.577462
#   соя                                                                                 -0.641355
# Картофель                                                                              1.228449
# Овощи                                                                                  1.923753
# Кукуруза на силос. зеленый \nкорм и сенаж                                              1.867377
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                            2.280800
# Сено многолетних трав                                                                 -0.415851
# Сено однолетних трав                                                                  -0.466590
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях  -0.620684
#
#                                                                                       1981-1985  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                          -0.518130
#   пшеница озимая                                                                      -0.397368
#   пшеница яровая                                                                      -0.552147
#   рожь озимая                                                                         -0.518130
#   кукуруза на зерно                                                                   -0.245989
#   ячмень озимый                                                                       -0.264699
#   ячмень яровой                                                                       -0.531737
#   овес                                                                                -0.530036
#   просо                                                                               -0.601473
#   гречиха                                                                             -0.669508
#   рис                                                                                 -0.166048
#   зернобобовые                                                                        -0.570857
# Лен-долгунец (волокно)                                                                -0.689919
# Сахарная свекла (фабричная)                                                            2.084213
# Масличные культуры                                                                    -0.598071
#   подсолнечник                                                                        -0.569156
#   соя                                                                                 -0.642294
# Картофель                                                                              1.029669
# Овощи                                                                                  1.931134
# Кукуруза на силос. зеленый \nкорм и сенаж                                              2.033187
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                            2.373363
# Сено многолетних трав                                                                 -0.342940
# Сено однолетних трав                                                                  -0.448394
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях  -0.594669
#
#                                                                                       1986-1990  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                          -0.498264
#   пшеница озимая                                                                      -0.336208
#   пшеница яровая                                                                      -0.554983
#   рожь озимая                                                                         -0.495563
#   кукуруза на зерно                                                                   -0.318652
#   ячмень озимый                                                                       -0.217368
#   ячмень яровой                                                                       -0.510418
#   овес                                                                                -0.534726
#   просо                                                                               -0.546880
#   гречиха                                                                             -0.637361
#   рис                                                                                 -0.243027
#   зернобобовые                                                                        -0.560385
# Лен-долгунец (волокно)                                                                -0.677875
# Сахарная свекла (фабричная)                                                            2.384970
# Масличные культуры                                                                    -0.561735
#   подсолнечник                                                                        -0.541478
#   соя                                                                                 -0.577941
# Картофель                                                                              0.764417
# Овощи                                                                                  1.480161
# Кукуруза на силос. зеленый \nкорм и сенаж                                              1.979831
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                            2.614548
# Сено многолетних трав                                                                 -0.365919
# Сено однолетних трав                                                                  -0.450998
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях  -0.594146
#
#                                                                                       1991-1995  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                          -0.481974
#   пшеница озимая                                                                      -0.342413
#   пшеница яровая                                                                      -0.546887
#   рожь озимая                                                                         -0.478729
#   кукуруза на зерно                                                                   -0.288860
#   ячмень озимый                                                                       -0.212588
#   ячмень яровой                                                                       -0.481974
#   овес                                                                                -0.516053
#   просо                                                                               -0.605308
#   гречиха                                                                             -0.652369
#   рис                                                                                 -0.262895
#   зернобобовые                                                                        -0.535527
# Лен-долгунец (волокно)                                                                -0.675088
# Сахарная свекла (фабричная)                                                            2.168073
# Масличные культуры                                                                    -0.576097
#   подсолнечник                                                                        -0.566360
#   соя                                                                                 -0.593948
# Картофель                                                                              1.048334
# Овощи                                                                                  1.616318
# Кукуруза на силос. зеленый \nкорм и сенаж                                              1.665002
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                            2.817196
# Сено многолетних трав                                                                 -0.415439
# Сено однолетних трав                                                                  -0.483597
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях  -0.598816
#
#                                                                                       1996-2000  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                          -0.471429
#   пшеница озимая                                                                      -0.368209
#   пшеница яровая                                                                      -0.511386
#   рожь озимая                                                                         -0.473094
#   кукуруза на зерно                                                                   -0.349895
#   ячмень озимый                                                                       -0.216708
#   ячмень яровой                                                                       -0.478089
#   овес                                                                                -0.496402
#   просо                                                                               -0.572985
#   гречиха                                                                             -0.622930
#   рис                                                                                 -0.253334
#   зернобобовые                                                                        -0.508056
# Лен-долгунец (волокно)                                                                -0.656227
# Сахарная свекла (фабричная)                                                            2.223958
# Масличные культуры                                                                    -0.582974
#   подсолнечник                                                                        -0.581309
#   соя                                                                                 -0.582974
# Картофель                                                                              1.025268
# Овощи                                                                                  1.707856
# Кукуруза на силос. зеленый \nкорм и сенаж                                              1.491426
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                            2.839952
# Сено многолетних трав                                                                 -0.484748
# Сено однолетних трав                                                                  -0.483083
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях  -0.594628
#
#                                                                                           2001  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                         -0.432921
#   пшеница озимая                                                                     -0.274056
#   пшеница яровая                                                                     -0.493519
#   рожь озимая                                                                        -0.442748
#   кукуруза на зерно                                                                  -0.455850
#   ячмень озимый                                                                      -0.156135
#   ячмень яровой                                                                      -0.439472
#   овес                                                                               -0.470590
#   просо                                                                              -0.621266
#   гречиха                                                                            -0.662211
#   рис                                                                                -0.179064
#   зернобобовые                                                                       -0.457488
# Лен-долгунец (волокно)                                                               -0.668762
# Сахарная свекла (фабричная)                                                           2.508541
# Масличные культуры                                                                   -0.621266
#   подсолнечник                                                                       -0.622904
#   соя                                                                                -0.596700
# Картофель                                                                             1.034534
# Овощи                                                                                 1.787915
# Кукуруза на силос. зеленый \nкорм и сенаж                                             1.198313
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           2.672319
# Сено многолетних трав                                                                -0.491881
# Сено однолетних трав                                                                 -0.495157
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях -0.619629
#
#                                                                                           2002  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                         -0.438987
#   пшеница озимая                                                                     -0.271340
#   пшеница яровая                                                                     -0.523624
#   рожь озимая                                                                        -0.448753
#   кукуруза на зерно                                                                  -0.294127
#   ячмень озимый                                                                      -0.116715
#   ячмень яровой                                                                      -0.460146
#   овес                                                                               -0.504092
#   просо                                                                              -0.619654
#   гречиха                                                                            -0.670111
#   рис                                                                                -0.144385
#   зернобобовые                                                                       -0.499209
# Лен-долгунец (волокно)                                                               -0.681505
# Сахарная свекла (фабричная)                                                           2.806518
# Масличные культуры                                                                   -0.598495
#   подсолнечник                                                                       -0.600123
#   соя                                                                                -0.567570
# Картофель                                                                             0.918461
# Овощи                                                                                 1.716003
# Кукуруза на силос. зеленый \nкорм и сенаж                                             1.162607
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           2.480991
# Сено многолетних трав                                                                -0.517113
# Сено однолетних трав                                                                 -0.500837
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях -0.627793
#
#                                                                                           2003  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                         -0.468034
#   пшеница озимая                                                                     -0.418786
#   пшеница яровая                                                                     -0.511488
#   рожь озимая                                                                        -0.456446
#   кукуруза на зерно                                                                  -0.262352
#   ячмень озимый                                                                      -0.344915
#   ячмень яровой                                                                      -0.449204
#   овес                                                                               -0.482519
#   просо                                                                              -0.524524
#   гречиха                                                                            -0.607086
#   рис                                                                                -0.269595
#   зернобобовые                                                                       -0.511488
# Лен-долгунец (волокно)                                                               -0.630262
# Сахарная свекла (фабричная)                                                           2.562146
# Масличные культуры                                                                   -0.582462
#   подсолнечник                                                                       -0.581014
#   соя                                                                                -0.583911
# Картофель                                                                             0.954355
# Овощи                                                                                 1.707554
# Кукуруза на силос. зеленый \nкорм и сенаж                                             1.490285
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           2.576631
# Сено многолетних трав                                                                -0.505694
# Сено однолетних трав                                                                 -0.491209
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях -0.609983
#
#                                                                                           2004  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                         -0.461772
#   пшеница озимая                                                                     -0.320372
#   пшеница яровая                                                                     -0.528469
#   рожь озимая                                                                        -0.505792
#   кукуруза на зерно                                                                  -0.174971
#   ячмень озимый                                                                      -0.213656
#   ячмень яровой                                                                      -0.488451
#   овес                                                                               -0.511128
#   просо                                                                              -0.553815
#   гречиха                                                                            -0.612509
#   рис                                                                                -0.209654
#   зернобобовые                                                                       -0.496454
# Лен-долгунец (волокно)                                                               -0.635186
# Сахарная свекла (фабричная)                                                           2.982506
# Масличные культуры                                                                   -0.576492
#   подсолнечник                                                                       -0.576492
#   соя                                                                                -0.579160
# Картофель                                                                             0.821495
# Овощи                                                                                 1.515153
# Кукуруза на силос. зеленый \nкорм и сенаж                                             1.381758
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           2.355546
# Сено многолетних трав                                                                -0.503124
# Сено однолетних трав                                                                 -0.503124
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях -0.605839
#
#                                                                                           2005  \
# type
# Зерновые культуры (в весе \nпосле доработки)                                         -0.468802
#   пшеница озимая                                                                     -0.342296
#   пшеница яровая                                                                     -0.539800
#   рожь озимая                                                                        -0.504946
#   кукуруза на зерно                                                                  -0.210627
#   ячмень озимый                                                                      -0.289371
#   ячмень яровой                                                                      -0.484292
#   овес                                                                               -0.521727
#   просо                                                                              -0.563035
#   гречиха                                                                            -0.613379
#   рис                                                                                -0.165447
#   зернобобовые                                                                       -0.508819
# Лен-долгунец (волокно)                                                               -0.626288
# Сахарная свекла (фабричная)                                                           2.932646
# Масличные культуры                                                                   -0.556581
#   подсолнечник                                                                       -0.553999
#   соя                                                                                -0.572071
# Картофель                                                                             0.854342
# Овощи                                                                                 1.551413
# Кукуруза на силос. зеленый \nкорм и сенаж                                             1.409417
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           2.364663
# Сено многолетних трав                                                                -0.495910
# Сено однолетних трав                                                                 -0.495910
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях -0.599180
#
#                                                                                           2006
# type
# Зерновые культуры (в весе \nпосле доработки)                                         -0.458382
#   пшеница озимая                                                                     -0.351358
#   пшеница яровая                                                                     -0.512483
#   рожь озимая                                                                        -0.479552
#   кукуруза на зерно                                                                  -0.254918
#   ячмень озимый                                                                      -0.253742
#   ячмень яровой                                                                      -0.468967
#   овес                                                                               -0.507778
#   просо                                                                              -0.558350
#   гречиха                                                                            -0.585400
#   рис                                                                                -0.164359
#   зернобобовые                                                                       -0.492489
# Лен-долгунец (волокно)                                                               -0.608922
# Сахарная свекла (фабричная)                                                           3.141638
# Масличные культуры                                                                   -0.548941
#   подсолнечник                                                                       -0.546589
#   соя                                                                                -0.564231
# Картофель                                                                             0.848257
# Овощи                                                                                 1.424543
# Кукуруза на силос. зеленый \nкорм и сенаж                                             1.165802
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                           2.353656
# Сено многолетних трав                                                                -0.497193
# Сено однолетних трав                                                                 -0.488961
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях -0.591281

# %%
link = linkage(df_scaled, 'ward', 'euclidean')
dn = dendrogram(link,
                # массив с названиями объектов для подписи по оси X
                labels=df_scaled.index.tolist(),
                # опция для более красивого отображения слишком ветввистой дендрограммы
                truncate_mode='lastp',
                # повернуть подписи вертикально
                color_threshold=5,
                orientation = "right",
                leaf_rotation=0.)

# %%
df['cluster'] = fcluster(link, 3, criterion='maxclust')

# %%
df.groupby('cluster').mean()
# Out:
#           1976-1980   1981-1985   1986-1990   1991-1995   1996-2000  \
# cluster
# 1         14.005263   14.215789   17.447368   15.189474   14.052632
# 2        160.000000  174.500000  238.500000  199.000000  195.500000
# 3        129.666667  141.333333  157.666667  134.333333  128.000000
#
#                2001        2002        2003        2004        2005  \
# cluster
# 1         16.263158   17.194737   16.352632   17.684211   17.663158
# 2        204.000000  209.000000  227.500000  253.500000  260.000000
# 3        127.666667  124.333333  145.666667  146.333333  153.333333
#
#                2006
# cluster
# 1         17.894737
# 2        291.500000
# 3        155.333333

# %%
df['cluster'].sort_values()
# Out:
# type
# Зерновые культуры (в весе \nпосле доработки)                                            1
# Сено многолетних трав                                                                   1
#   соя                                                                                   1
#   подсолнечник                                                                          1
# Масличные культуры                                                                      1
# Лен-долгунец (волокно)                                                                  1
# Сено однолетних трав                                                                    1
#   рис                                                                                   1
#   гречиха                                                                               1
#   зернобобовые                                                                          1
#   овес                                                                                  1
#   ячмень яровой                                                                         1
#   ячмень озимый                                                                         1
#   кукуруза на зерно                                                                     1
#   рожь озимая                                                                           1
#   пшеница яровая                                                                        1
#   пшеница озимая                                                                        1
#   просо                                                                                 1
# Сено естественных сенокосов (включая улучшенные) в сельскохозяйственных организациях    1
# Сахарная свекла (фабричная)                                                             2
# Кормовые корнеплоды (включая сахарную свеклу на корм скоту)                             2
# Картофель                                                                               3
# Овощи                                                                                   3
# Кукуруза на силос. зеленый \nкорм и сенаж                                               3
# Name: cluster, dtype: int32
