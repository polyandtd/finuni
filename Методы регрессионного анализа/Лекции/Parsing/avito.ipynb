# %%
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
def get_html(url):
    r = requests.get(url)
    return r.text

def get_total_pages(html):
    soup = BeautifulSoup(html, 'lxml')
    divs = soup.find('div', class_ = 'pagination-pages clearfix')
    pages = divs.find_all('a', class_ = 'pagination-page')[-1].get('href')
    total_pages = pages.split('=')[1].split('&')[0]
    return int(total_pages)

def write_csv(data):
    with open('avito.csv', 'a', encoding = 'Utf-8') as f:
        writer = csv.writer(f)
        writer.writerow((data['title'],
                         data['price'],
                         data['metro'],
                         data['url']))
        
def get_page_data(html):
    soup = BeautifulSoup(html, 'lxml')
    divs = soup.find('div', class_ = 'catalog-list')
    ads = divs.find_all('div', class_ = 'item_table')
    for ad in ads:
        try:
            div = ad.find('div', class_ = 'description').find('h3')
            if 'meizu' not in div.text.lower():
                continue
            else:
                title = div.text.strip()
        except:
            title = ''
        try:
            div = ad.find('div', class_ = 'description').find('h3')
            url = 'https://avito.ru' + div.find('a').get('href')
        except:
            url = ''
        try:
            price = ad.find('div', class_ = 'about').text.strip()
        except:
            price = ''
        try:
            div = ad.find('div', class_ = 'data')
            metro = div.find_all('div')[0].text.strip()
        except:
            metro = ''
        data = {'title': title,
                'price': price,
                'metro': metro,
                'url': url}
        write_csv(data)
        
def main():
    url = 'https://www.avito.ru/moskva/telefony?p=1&q=meizu'
    base_url = 'https://avito.ru/moskva/telefony?'
    page_part = 'p='
    query_par = '&q=meizu'
    # total_pages = get_total_pages(get_html(url))
    for i in range(1, 3):
        url_gen = base_url + page_part + str(i) + query_par
        html = get_html(url_gen)
        get_page_data(html)
if __name__ == '__main__':
    main()

# %%
avito = pd.read_csv(r'avito.csv', sep =',', header = None)
avito.columns = ['Model', 'Price', 'Metro', 'Reference']
avito
# Out:
#                                                 Model       Price  \
# 0                                               Meizu  14 000   ₽
# 1                             Продам Meizu m2 note 16   1 000   ₽
# 2                             Meizu PRO 5 на запчасти     500   ₽
# 3                                    Meizu pro 6 32GB   5 999   ₽
# 4                         Meizu M6 Note 3/32GB "Blue"   5 500   ₽
# 5                                       Meizu m5 note   3 500   ₽
# 6                                            Meizu m6   4 000   ₽
# 7                                          Meizu u 20   5 000   ₽
# 8                                      Meizu MX2 64GB   2 500   ₽
# 9                                       Meizu M3 mini   2 000   ₽
# 10                                 Meizu m5 Note 3/32   3 499   ₽
# 11                                   Meizu 5 PRO 4/64   8 000   ₽
# 12                                              Meizu   5 000   ₽
# 13                              Meizu MX5 на запчасти     500   ₽
# 14                                      Meizu m6 gold   3 500   ₽
# 15                                   Meizu pro 7 plus  10 000   ₽
# 16                                    Meizu mx5 32 gb   4 500   ₽
# 17                                         Meizu m3 s   2 700   ₽
# 18                                          Meizu M3S   4 500   ₽
# 19    Meizu U10 в отличном состоянии, полный комплект   4 000   ₽
# 20                                        Meizu 7 pro   3 500   ₽
# 21                          Телефон Meizu PRO 7 64 gb  12 000   ₽
# 22                                              Meizu   2 000   ₽
# 23                                 Meizu M3 note 32gb   2 500   ₽
# 24                                      Meizu m2 note   3 500   ₽
# 25                                         Meizu 16th  21 000   ₽
# 26                                 Meizu m3 note 16GB   3 500   ₽
# 27                      Meizu M463 Note, M5 Note 3/32   1 600   ₽
# 28                                   Чехол Meizu MX 6     299   ₽
# 29                Meizu m6 3/32 в идиальном состоянии   3 990   ₽
# ..                                                ...         ...
# 70                                              Meizu  10 500   ₽
# 71  Дисплей Meizu M5c/Meizu A5 (M710h) +тачскрин (...     880   ₽
# 72                       Смартфон Meizu 15 64Gb Black  19 300   ₽
# 73                                      Meizu M2 mini   3 000   ₽
# 74  Дисплей Meizu M5c/Meizu A5 (M710h) +тачскрин (...     880   ₽
# 75                                      Meizu M5 Note   3 800   ₽
# 76                                          Meizu U10   4 000   ₽
# 77                                          Meizu M3s   2 000   ₽
# 78                                     Meizu m3s 32gb   3 500   ₽
# 79                                          Meizu m3s   3 500   ₽
# 80                                          Meizu M8c   5 000   ₽
# 81                                      Meizu M5 note   6 000   ₽
# 82                                  Meizu m3 not 16гб   4 000   ₽
# 83                                          Meizu M5s   6 509   ₽
# 84                                Meizu 15 64gb white  11 990   ₽
# 85                                        Meizu pro 6   8 000   ₽
# 86                   Беспроводные наушники Meizu EP51     500   ₽
# 87                                          Meizu M3S   4 000   ₽
# 88                                   Meizu U10. 32 Гб   4 500   ₽
# 89                                  Meizu модельY685H   5 000   ₽
# 90                                     Meizu U10 32Gb   4 500   ₽
# 91                                   Meizu U 20 16 GB   3 500   ₽
# 92              Meizu MX6 32Gb память, 4Gb оперативка   5 500   ₽
# 93                                 Аккумуляторы Meizu     400   ₽
# 94             Meizu U10 3/32gb, чеки, документы есть   5 000   ₽
# 95                                 Meizu m3 note 3/32   4 250   ₽
# 96                                   Meizu pro 6 3/32   6 000   ₽
# 97                                         Meizu pro6   3 000   ₽
# 98                                      Meizu M6 note   4 999   ₽
# 99             Meizu pro 7 global глобальная прошивка  10 100   ₽
#
#                               Metro  \
# 0                         Бутырская
# 1               Зябликово, 1,2\t км
# 2              Охотный ряд, 100\t м
# 3   Улица академика Янгеля, 700\t м
# 4                  Аннино, 3,3\t км
# 5             Марьина Роща, 200\t м
# 6              Театральная, 100\t м
# 7                Кузьминки, 700\t м
# 8         Октябрьское поле, 100\t м
# 9                  Октябрьское поле
# 10                    Домодедовская
# 11       Площадь революции, 400\t м
# 12              Некрасовка, 100\t м
# 13                      Театральная
# 14                 Ясенево, 100\t м
# 15                      Теплый стан
# 16             Теплый стан, 100\t м
# 17           Волоколамская, 500\t м
# 18               Зябликово, 800\t м
# 19              Тропарево, 1,9\t км
# 20                Царицыно, 100\t м
# 21          Водный стадион, 200\t м
# 22                          Ховрино
# 23              Медведково, 200\t м
# 24      Славянский бульвар, 800\t м
# 25                Коньково, 300\t м
# 26                             ВДНХ
# 27                        Зябликово
# 28       Площадь революции, 400\t м
# 29                     Измайловская
# ..                              ...
# 70           Преображенская площадь
# 71                Царицыно, 300\t м
# 72      Славянский бульвар, 300\t м
# 73              Щелковская, 100\t м
# 74                Царицыно, 300\t м
# 75                             ВДНХ
# 76              Медведково, 700\t м
# 77                         Отрадное
# 78                Люблино, 1,5\t км
# 79             Дмитровская, 700\t м
# 80             Шипиловская, 500\t м
# 81             Селигерская, 100\t м
# 82                      Шаболовская
# 83             Сходненская, 300\t м
# 84             Савеловская, 300\t м
# 85                Жулебино, 100\t м
# 86                          Беговая
# 87                           Перово
# 88             Проспект Вернадского
# 89                    ВДНХ, 200\t м
# 90                 Курская, 300\t м
# 91                Минская, 1,8\t км
# 92             Кунцевская, 1,6\t км
# 93                Пражская, 200\t м
# 94                Тульская, 100\t м
# 95                Солнцево, 500\t м
# 96           Комсомольская, 100\t м
# 97            Юго-Западная, 100\t м
# 98       Октябрьское поле, 1,9\t км
# 99               Тушинская, 100\t м
#
#                                             Reference
# 0   https://avito.ru/moskva/telefony/meizu_1813552080
# 1   https://avito.ru/moskva/telefony/prodam_meizu_...
# 2   https://avito.ru/moskva/telefony/meizu_pro_5_n...
